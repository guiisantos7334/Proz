# %% [markdown]
# <a href="https://colab.research.google.com/github/guiisantos7334/Proz/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(20,0,-1):
  if(i==13):
    continue
  print("Andar numero",i)
# Out:
# Andar numero 20
# Andar numero 19
# Andar numero 18
# Andar numero 17
# Andar numero 16
# Andar numero 15
# Andar numero 14
# Andar numero 12
# Andar numero 11
# Andar numero 10
# Andar numero 9
# Andar numero 8
# Andar numero 7
# Andar numero 6
# Andar numero 5
# Andar numero 4
# Andar numero 3
# Andar numero 2
# Andar numero 1

# %%
i=20
while(i>=1):
  if(i==13):
    i=i-1
    continue
  print("Andar numero", i)
  i=i-1
# Out:
# Andar numero 20
# Andar numero 19
# Andar numero 18
# Andar numero 17
# Andar numero 16
# Andar numero 15
# Andar numero 14
# Andar numero 12
# Andar numero 11
# Andar numero 10
# Andar numero 9
# Andar numero 8
# Andar numero 7
# Andar numero 6
# Andar numero 5
# Andar numero 4
# Andar numero 3
# Andar numero 2
# Andar numero 1
