# %% [markdown]
# <a href="https://colab.research.google.com/github/guiisantos7334/Proz/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome=str(input("Digite o seu nome completo:"))
while True:
  try:
    data=int(input("Digite seu ano de nascimento:"))


    if (data<1922 or data>2021):
      print("Data invalida")

    else:
      idade= 2022-data
      print("Nome:",nome)
      print("Idade:",idade)
      break

  except ValueError:
    print("Caracter invalido")
# Out:
# Digite o seu nome completo:Guilherme
# Digite seu ano de nascimento:2003
# Nome: Guilherme
# Idade: 19
